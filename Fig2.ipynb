# %%
# %run Nonconvex_training.ipynb 
L=4
opt=False

# %% [markdown]
# # Left plot

# %%
move0toneg1 = False
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 0.1711833
# [201, 1] loss: 0.0000010
# [401, 1] loss: 0.0000001
# [601, 1] loss: 0.0000002
# [801, 1] loss: 0.0000001
# Finished Training
# objective =  2.1798316880755534e-07
# kink =  4.256756756756757

# %% [markdown]
# # Right plot

# %%
move0toneg1 = True
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 0.1711833
# [200001, 1] loss: 0.0000001
# [400001, 1] loss: 0.0000001
# [600001, 1] loss: 0.0000001
# [800001, 1] loss: 0.0000001
# Finished Training
# objective =  1.0127532270245476e-07
# kink =  4.995495495495495
