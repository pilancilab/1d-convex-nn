# %%
import os
# %run convex_training.ipynb
save=True
path = './fig18'
labelyaxis = True
if save:
    if not os.path.exists(path):
        os.mkdir(path)
# Out:
# (CVXPY) Mar 18 12:22:53 PM: Encountered unexpected exception importing solver SCS:
# ImportError('dlopen(/Users/emi/Library/Python/3.7/lib/python/site-packages/_scs_direct.cpython-37m-darwin.so, 2): Symbol not found: _aligned_alloc\n  Referenced from: /Users/emi/Library/Python/3.7/lib/python/site-packages/scs/.dylibs/libgomp.1.dylib (which was built for Mac OS X 10.15)\n  Expected in: /usr/lib/libSystem.B.dylib\n in /Users/emi/Library/Python/3.7/lib/python/site-packages/scs/.dylibs/libgomp.1.dylib')

# %% [markdown]
# # Neural net predictions (left column)

# %% [markdown]
# L=2

# %%
L=2
analyze_cvx_nn(L=L, dataset='bounce', save=save, figtitle=path + "/LassoL"+ str(L), labelyaxis=labelyaxis)
# Out:
# optimal objective =  4e-08
# s,j,k= [1] [1] 0
# s,j,k= [1] [2] 0

# %% [markdown]
# L=3

# %%
L=3
analyze_cvx_nn(L=L, dataset='bounce', save=save, figtitle=path + "/LassoL"+ str(L), labelyaxis=labelyaxis)
# Out:
# optimal objective =  4.0000000374258676e-08
# s,j,k= [-1 -1] [0 1] 0
# s,j,k= [-1 -1] [0 2] 0

# %% [markdown]
# L=4

# %%
L=4
analyze_cvx_nn(L=L, dataset='bounce', save=save, figtitle=path + "/LassoL"+ str(L),labelyaxis=labelyaxis)
# Out:
# optimal objective =  9e-08
# s,j,k= [1 1 1] [2 2 3] 1
# s,j,k= [1 1 1] [3 2 3] 1
