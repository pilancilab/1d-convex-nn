# %%
import os
# %run Nonconvex_training.ipynb 
opt=True
move0toneg1 = False

save=True
path = './fig3'
if save:
    if not os.path.exists(path):
        os.mkdir(path)

# %% [markdown]
# # Neural nets trained with Adam (plots in left-most column)

# %% [markdown]
# L=2

# %%
L=2
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
if save:
    plt.savefig(path + "/Adam" + str(L) + ".pdf", format="pdf", bbox_inches="tight")
# Out:
# [1, 1] loss: 0.9797764
# [201, 1] loss: 0.0000011
# [401, 1] loss: 0.0000010
# [601, 1] loss: 0.0000009
# [801, 1] loss: 0.0000015
# Finished Training
# objective =  1.3156813983156744e-06
# kink =  9.974474474474475

# %% [markdown]
# L=3

# %%
L=3
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
if save:
    plt.savefig(path + "/AdamL" + str(L) + ".pdf", format="pdf", bbox_inches="tight")
# Out:
# [1, 1] loss: 21.2902018
# [20001, 1] loss: 0.0000010
# [40001, 1] loss: 0.0000089
# [60001, 1] loss: 0.0000006
# [80001, 1] loss: 0.0001888
# Finished Training
# objective =  3.255797841775099e-06
# kink =  9.433933933933934

# %% [markdown]
# L=4

# %%
L=4
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
if save:
    plt.savefig(path + "/AdamL" + str(L) + ".pdf", format="pdf", bbox_inches="tight")
# Out:
# [1, 1] loss: 0.4612573
# [201, 1] loss: 0.0000003
# [401, 1] loss: 0.0000006
# [601, 1] loss: 0.0000016
# [801, 1] loss: 0.0000006
# Finished Training
# objective =  2.9577544860577956e-07
# kink =  7.992492492492492

# %% [markdown]
# # Neural nets trained with Lasso (plots in middle and right-most columns)

# %%
# %run convex_training.ipynb
# Out:
# (CVXPY) Mar 18 12:30:08 PM: Encountered unexpected exception importing solver SCS:
# ImportError('dlopen(/Users/emi/Library/Python/3.7/lib/python/site-packages/_scs_direct.cpython-37m-darwin.so, 2): Symbol not found: _aligned_alloc\n  Referenced from: /Users/emi/Library/Python/3.7/lib/python/site-packages/scs/.dylibs/libgomp.1.dylib (which was built for Mac OS X 10.15)\n  Expected in: /usr/lib/libSystem.B.dylib\n in /Users/emi/Library/Python/3.7/lib/python/site-packages/scs/.dylibs/libgomp.1.dylib')

# %% [markdown]
# L=2

# %%
L=2
analyze_cvx_nn(L=L, dataset='opt', save=save, figtitle=path + "/LassoL"+ str(L))

# %% [markdown]
# L=3

# %%
L=3
analyze_cvx_nn(L=L, dataset='opt', save=save, figtitle=path + "/LassoL"+ str(L))

# %% [markdown]
# L=4

# %%
L=4
analyze_cvx_nn(L=L, dataset='opt', save=save, figtitle=path + "/LassoL"+ str(L))
