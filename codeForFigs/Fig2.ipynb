# %%
import os
# %run Nonconvex_training.ipynb 
L=4
opt=False

save=True
path = './fig2'
if save:
    if not os.path.exists(path):
        os.mkdir(path)

# %% [markdown]
# # Left plot

# %%
move0toneg1 = False
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
if save:
    plt.savefig(path + "/left.pdf", format="pdf", bbox_inches="tight")
# Out:
# [1, 1] loss: 0.1711832
# [201, 1] loss: 0.0000009
# [401, 1] loss: 0.0000000
# [601, 1] loss: 0.0000018
# [801, 1] loss: 0.0000003
# Finished Training
# objective =  4.832638259166235e-08
# kink =  4.248748748748748

# %% [markdown]
# # Right plot

# %%
move0toneg1 = True
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
if save:
    plt.savefig(path + "/right.pdf", format="pdf", bbox_inches="tight")
# Out:
# [1, 1] loss: 0.1711832
# [3001, 1] loss: 0.0000000
# [6001, 1] loss: 0.0000001
# [9001, 1] loss: 0.0000001
# [12001, 1] loss: 0.0000001
# Finished Training
# objective =  1.6787663195803143e-07
# kink =  5.085585585585585
