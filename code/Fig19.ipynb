# %%
# %run Nonconvex_training.ipynb 
opt=False
move0toneg1 = False

# %% [markdown]
# # Training with Adam (plots in left column)

# %%
L=3
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 16.6506410
# [201, 1] loss: 0.0815993
# [401, 1] loss: 0.0000051
# [601, 1] loss: 0.0000039
# [801, 1] loss: 0.0000041
# Finished Training
# objective =  4.250246138462898e-06
# kink =  5.986486486486487

# %%
L=4
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 0.1711833
# [201, 1] loss: 0.0000010
# [401, 1] loss: 0.0000001
# [601, 1] loss: 0.0000002
# [801, 1] loss: 0.0000001
# Finished Training
# objective =  2.1798316880755534e-07
# kink =  4.256756756756757

# %% [markdown]
# # Training with Lasso (right column)

# %%
# %run convex_training.ipynb

# %% [markdown]
# L=3

# %%
analyze_cvx_nn(L=3, dataset='zshape')
# Out:
# optimal objective =  1.4999999949889037e-08

# %% [markdown]
# L=4

# %%
analyze_cvx_nn(L=4, dataset='zshape')
# Out:
# optimal objective =  3.0000000000000004e-08
