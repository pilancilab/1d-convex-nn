# %%
# %run convex_training.ipynb

# %% [markdown]
# # Neural net predictions (left column)

# %% [markdown]
# L=2

# %%
analyze_cvx_nn(L=2, dataset='bounce')
# Out:
# optimal objective =  4e-08
# s,j,k= [1] [1] 0
# s,j,k= [1] [2] 0

# %% [markdown]
# L=3

# %%
analyze_cvx_nn(L=3, dataset='bounce')
# Out:
# optimal objective =  4.0000000374258676e-08
# s,j,k= [-1 -1] [0 1] 0
# s,j,k= [-1 -1] [0 2] 0

# %% [markdown]
# L=4

# %%
analyze_cvx_nn(L=4, dataset='bounce')
# Out:
# optimal objective =  9e-08
# s,j,k= [1 1 1] [2 2 3] 1
# s,j,k= [1 1 1] [3 2 3] 1
