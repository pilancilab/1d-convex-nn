# %%
# %run Nonconvex_training.ipynb 
opt=True
move0toneg1 = False

# %% [markdown]
# # Neural nets trained with Adam (plots in left-most column)

# %% [markdown]
# L=2

# %%
L=2
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 0.9797764
# [201, 1] loss: 0.0000011
# [401, 1] loss: 0.0000010
# [601, 1] loss: 0.0000009
# [801, 1] loss: 0.0000015
# Finished Training
# objective =  1.3156813983156744e-06
# kink =  9.974474474474475

# %% [markdown]
# L=3

# %%
L=3
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 21.2902019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/nk/f5jj8pqx14ngfhfghkmynmmw0000gr/T/ipykernel_71915/3792354230.py in <module>
#       1 L=3
# ----> 2 net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
#       3 plotresults(X=X,y=y,L=L)
#
# /var/folders/nk/f5jj8pqx14ngfhfghkmynmmw0000gr/T/ipykernel_71915/4293071889.py in nonconvex_nn(L, opt, move0toneg1, debug, verbose, initkinkat4, par)
#     221         net.apply(print_weights)
#     222
# --> 223     net, loss_vec = train(net=net, num_epochs=num_epochs, ds_train=ds_train, β=β)
#     224     if num_epochs>1:
#     225         print('objective = ', loss_vec[-1])
#
# /var/folders/nk/f5jj8pqx14ngfhfghkmynmmw0000gr/T/ipykernel_71915/4293071889.py in train(net, num_epochs, ds_train, β, use_scheduler, opt_method)
#     168
#     169             # forward + backward + optimize
# --> 170             outputs = net(inputs)
#     171             loss = criterion(outputs, labels.reshape(-1,1))
#     172             non_bias_params = []
#
# ~/Library/Python/3.7/lib/python/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/nk/f5jj8pqx14ngfhfghkmynmmw0000gr/T/ipykernel_71915/1039193608.py in forward(self, x)
#      48             x = self.last(x)
#      49         else:
# ---> 50             for i in range(self.L-2):
#      51                 #x = F.relu(self.one2one(x))
#      52                 if i==0:
#
# KeyboardInterrupt:

# %% [markdown]
# L=4

# %%
L=4
net, loss_vec, X, y, num_epochs = nonconvex_nn(L=L,opt=opt,move0toneg1=move0toneg1)
plotresults(X=X,y=y,L=L)
# Out:
# [1, 1] loss: 0.4612578
# [201, 1] loss: 0.0000007
# [401, 1] loss: 0.0000009
# [601, 1] loss: 0.0000009
# [801, 1] loss: 0.0000006
# Finished Training
# objective =  5.878145148094441e-07
# kink =  7.992492492492492

# %% [markdown]
# # Neural nets trained with Adam (plots in middle and right-most columns)

# %%
# %run convex_training.ipynb

# %% [markdown]
# L=2

# %%
analyze_cvx_nn(L=2, dataset='opt')

# %% [markdown]
# L=3

# %%
analyze_cvx_nn(L=3, dataset='opt')

# %% [markdown]
# L=4

# %%
analyze_cvx_nn(L=4, dataset='opt')
